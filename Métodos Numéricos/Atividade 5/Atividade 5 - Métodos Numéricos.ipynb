# %% [markdown]
# # Questão 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange
from scipy.interpolate import BarycentricInterpolator

# Dados da tabela
x_values = [1, 2, 5, 6, 7, 8, 10, 13, 17, 20, 23, 24, 25, 27, 27.7, 28, 29, 30]
f_values = [3.0, 3.7, 3.9, 4.2, 5.7, 6.6, 7.1, 6.7, 4.5, 7.0, 6.1, 5.6, 5.8, 5.2, 4.1, 4.3, 4.1, 3.0]

# Criar uma função para interpolação utilizando Lagrange
lagrange_interp = lagrange(x_values, f_values)

# Criar uma função para interpolação utilizando Newton
newton_interp = BarycentricInterpolator(x_values, f_values)

# Gerar pontos para o gráfico
x_range = np.linspace(min(x_values), max(x_values), 1000)
lagrange_y = lagrange_interp(x_range)
newton_y = newton_interp(x_range)

# Plotar os resultados
plt.figure(figsize=(10, 6))
plt.scatter(x_values, f_values, color='red', label='Pontos da Tabela')
plt.plot(x_range, lagrange_y, label='Interpolação de Lagrange')
plt.plot(x_range, newton_y, label='Interpolação de Newton')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Interpolação Polinomial')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Questão 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# Dados da tabela
x_values = [1, 2, 5, 6, 7, 8, 10, 13, 17, 20, 23, 24, 25, 27, 27.7, 28, 29, 30]
f_values = [3.0, 3.7, 3.9, 4.2, 5.7, 6.6, 7.1, 6.7, 4.5, 7.0, 6.1, 5.6, 5.8, 5.2, 4.1, 4.3, 4.1, 3.0]

# Criar uma função de spline cúbico
spline_interp = CubicSpline(x_values, f_values)

# Gerar pontos para o gráfico
x_range = np.linspace(min(x_values), max(x_values), 1000)
spline_y = spline_interp(x_range)

# Plotar os resultados
plt.figure(figsize=(10, 6))
plt.scatter(x_values, f_values, color='red', label='Pontos da Tabela')
plt.plot(x_range, spline_y, label='Spline Cúbico')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Spline Cúbico para Interpolação')
plt.legend()
plt.grid(True)
plt.show()
